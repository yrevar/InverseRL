# %%
import numpy as np
from utils.NavigationGridView import NavigationGridView
CellParams = NavigationGridView.CellParams
GridParams = NavigationGridView.GridParams

import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## $\phi \in \mathcal{R}^{1}$

# %%
NavigationGridView(np.random.rand(4,4,1)).render(CellParams(spines=True, vmin=0, vmax=1)).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{2}$

# %%
NavigationGridView(np.random.rand(4,4,2)).render(CellParams(
    spines=True, vmin=None, vmax=None, xlim=[0,1], ylim=[0,1])).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{3}$

# %%
NavigationGridView(np.random.rand(4,4,3)).render(CellParams(spines=True, xlim=[0,2], ylim=[0,1])).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{2} \times \mathcal{R}^{2}$

# %%
NavigationGridView(np.random.rand(4,4,2,2)).render(CellParams(spines=True, vmin=None, vmax=None)).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{16} \times \mathcal{R}^{16}$

# %%
NavigationGridView(np.random.rand(4,4,16,16)).render(CellParams(spines=True, vmin=None, vmax=None)).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{2} \times \mathcal{R}^{2} \times \mathcal{R}^{3}$

# %%
NavigationGridView(np.random.rand(4,4,2,2,3)).render(CellParams(spines=True, vmin=None, vmax=None)).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{16} \times \mathcal{R}^{16} \times \mathcal{R}^{3}$

# %%
NavigationGridView(np.random.rand(4,4,16,16,3)).render(CellParams(spines=True, vmin=None, vmax=None)).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])

# %% [markdown]
# ## $\phi \in \mathcal{R}^{64} \times \mathcal{R}^{64} \times \mathcal{R}^{3}$

# %%
NavigationGridView(np.random.rand(4,4,64,64,3)).render(CellParams(spines=True, vmin=None, vmax=None)).add_trajectory(
    [(1,1), (1,2), (1,3), (2,3), (3,3)])
